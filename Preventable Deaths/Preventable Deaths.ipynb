# %%
#importing packages and reading in csv files
import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline 
sns.set(color_codes=True)
white_df=pd.read_csv('white_data.csv')
black_df=pd.read_csv('black_data.csv')
df=pd.read_csv('680_1_data.csv')

# %%
#viewing white df
print(white_df)
# Out:
#     Year  Unemployment  Uninsured  Smoker  Obese  HIV Death  \
# 0   2005           4.4       15.9    27.7   33.1        2.2
# 1   2006           4.0       16.7    27.1   32.2        2.1
# 2   2007           4.1       16.3    26.6   31.4        1.9
# 3   2008           5.0       16.7    26.7   32.0        1.7
# 4   2009           8.6       17.1    28.1   31.2        1.5
# 5   2010           8.7       17.6    24.6   30.0        1.4
# 6   2011           7.9       16.7    24.3   30.1        1.3
# 7   2012           7.3       16.7    24.8   31.1        1.2
# 8   2013           6.5       16.3    23.4   28.8        1.2
# 9   2014           5.3       13.3    21.7   29.4        1.1
# 10  2015           4.5       10.7    18.9   28.3        1.1
# 11  2016           4.2       10.2    19.4   29.0        1.0
# 12  2017           3.7       10.6    17.4   28.4        0.9
#
#     Flu-Related Death  Cancer Death  Heart Disease Death  Diabetes Death  \
# ...

# %%
#viewing black df
print(black_df)
# Out:
#     Year  Unemployment  Uninsured  Smoker  Obese  HIV Death  \
# 0   2005          10.1       18.4    25.1   22.7       19.2
# 1   2006           8.7       18.1    26.2   23.3       18.3
# 2   2007           8.5       17.0    24.2   22.7       17.0
# 3   2008          11.1       18.0    22.0   23.4       14.9
# 4   2009          14.8       18.9    22.5   21.7       13.7
# 5   2010          15.6       20.6    22.6   22.6       11.6
# 6   2011          15.5       19.0    22.7   22.0       10.3
# 7   2012          13.7       18.0    21.3   21.0        9.5
# 8   2013          13.0       18.9    20.9   21.3        8.9
# 9   2014          10.7       13.7    22.2   22.5        8.3
# 10  2015           9.6       11.3    20.2   22.7        7.9
# 11  2016           8.7       11.5    19.5   23.6        7.2
# 12  2017           7.6       11.2    20.1   23.1        6.6
#
#     Flu-Related Death  Cancer Death  Heart Disease Death  Diabetes Death  \
# ...

# %%
#viewing all data
print(df)
# Out:
#     Year   Race  Unemployment  Uninsured  Smoker  Obese  HIV Death  \
# 0   2005  White           4.4       15.9    27.7   33.1        2.2
# 1   2005  Black          10.1       18.4    25.1   22.7       19.2
# 2   2006  White           4.0       16.7    27.1   32.2        2.1
# 3   2006  Black           8.7       18.1    26.2   23.3       18.3
# 4   2007  White           4.1       16.3    26.6   31.4        1.9
# 5   2007  Black           8.5       17.0    24.2   22.7       17.0
# 6   2008  White           5.0       16.7    26.7   32.0        1.7
# 7   2008  Black          11.1       18.0    22.0   23.4       14.9
# 8   2009  White           8.6       17.1    28.1   31.2        1.5
# 9   2009  Black          14.8       18.9    22.5   21.7       13.7
# 10  2010  White           8.7       17.6    24.6   30.0        1.4
# 11  2010  Black          15.6       20.6    22.6   22.6       11.6
# 12  2011  White           7.9       16.7    24.3   30.1        1.3
# ...

# %%
# Checking the data type
df.dtypes
# Out:
# Year                     int64
# Race                    object
# Unemployment           float64
# Uninsured              float64
# Smoker                 float64
# Obese                  float64
# HIV Death              float64
# Flu-Related Death      float64
# Cancer Death           float64
# Heart Disease Death    float64
# Diabetes Death         float64
# Homicide               float64
# Suicide                float64
# dtype: object

# %%
#checking for outliers
sns.boxplot(x=black_df.Unemployment)
# Out:
# <AxesSubplot:xlabel='Unemployment'>

# %%
#checking for outliers
sns.boxplot(x=black_df.Uninsured)
# Out:
# <AxesSubplot:xlabel='Uninsured'>

# %%
#checking for outliers 
sns.boxplot(x=black_df.Smoker)

#one outlier
# Out:
# <AxesSubplot:xlabel='Smoker'>

# %%
#checking for outliers
sns.boxplot(x=black_df.Obese)
# Out:
# <AxesSubplot:xlabel='Obese'>

# %%
#checking for outliers 
sns.boxplot(x=black_df['HIV Death'])
# Out:
# <AxesSubplot:xlabel='HIV Death'>

# %%
#checking for outliers 
sns.boxplot(x=black_df['Flu-Related Death'])
# Out:
# <AxesSubplot:xlabel='Flu-Related Death'>

# %%
#checking for outliers
sns.boxplot(x=black_df['Cancer Death'])
# Out:
# <AxesSubplot:xlabel='Cancer Death'>

# %%
#checking for outliers
sns.boxplot(x=black_df['Heart Disease Death'])
# Out:
# <AxesSubplot:xlabel='Heart Disease Death'>

# %%
#checking for outliers
sns.boxplot(x=black_df['Diabetes Death'])
#one outlier
# Out:
# <AxesSubplot:xlabel='Diabetes Death'>

# %%
#checking for outliers
sns.boxplot(x=black_df['Homicide '])
# Out:
# <AxesSubplot:xlabel='Homicide '>

# %%
#checking for outliers
sns.boxplot(x=black_df['Suicide'])

#one outlier
# Out:
# <AxesSubplot:xlabel='Suicide'>

# %%
#checking for outliers
sns.boxplot(x=white_df['Unemployment'])
# Out:
# <AxesSubplot:xlabel='Unemployment'>

# %%
#checking for outliers
sns.boxplot(x=white_df['Uninsured'])
# Out:
# <AxesSubplot:xlabel='Uninsured'>

# %%
#checking for outliers
sns.boxplot(x=white_df['Smoker'])
# Out:
# <AxesSubplot:xlabel='Smoker'>

# %%
#checking for outliers
sns.boxplot(x=white_df['Obese'])
# Out:
# <AxesSubplot:xlabel='Obese'>

# %%
#checking for outliers
sns.boxplot(x=white_df['HIV Death'])
# Out:
# <AxesSubplot:xlabel='HIV Death'>

# %%
#checking for outliers
sns.boxplot(x=white_df['Flu-Related Death'])

#one outlier
# Out:
# <AxesSubplot:xlabel='Flu-Related Death'>

# %%
#checking for outliers
sns.boxplot(x=white_df['Cancer Death'])
# Out:
# <AxesSubplot:xlabel='Cancer Death'>

# %%
#checking for outliers
sns.boxplot(x=white_df['Heart Disease Death'])
# Out:
# <AxesSubplot:xlabel='Heart Disease Death'>

# %%
#checking for outliers
sns.boxplot(x=white_df['Diabetes Death'])

#one outlier
# Out:
# <AxesSubplot:xlabel='Diabetes Death'>

# %%
#checking for outliers
sns.boxplot(x=white_df['Homicide '])
# Out:
# <AxesSubplot:xlabel='Homicide '>

# %%
#checking for outliers
sns.boxplot(x=white_df['Suicide'])
# Out:
# <AxesSubplot:xlabel='Suicide'>

# %%
#no outliers will be dropped because the year range is relatively small and one outlier should not majorly impact
#the results of the data findings

# %%
#creating barchart to compare unemployment
sns.barplot(x='Year', y='Unemployment', hue='Race', data=df)
plt.ylabel('Unemployment Percent')
plt.title('Unemployment Rate by Race')
# Out:
# Text(0.5, 1.0, 'Unemployment Rate by Race')

# %%
#creating barchart to compare uninsured
sns.barplot(x='Year', y='Uninsured', hue='Race', data=df)
plt.ylabel('Unemployment Percent')
plt.ylim(7.5,21)
plt.title('Uninsurement Rate by Race')
# Out:
# Text(0.5, 1.0, 'Uninsurement Rate by Race')

# %%
#creating barchart to compare smoking
sns.barplot(x='Year', y='Smoker', hue='Race', data=df)
plt.ylabel('Smoking Percent')

plt.title('Percent of Smokers by Race')
# Out:
# Text(0.5, 1.0, 'Percent of Smokers by Race')

# %%
#creating barchart to compare obesity
sns.barplot(x='Year', y='Obese', hue='Race', data=df)
plt.ylabel('Obesity Percent')

plt.title('Obesity by Race')
# Out:
# Text(0.5, 1.0, 'Obesity by Race')

# %%
#creating barchart to compare hiv deaths
sns.barplot(x='Year', y='HIV Death', hue='Race', data=df)
plt.ylabel('# of HIV Deaths/100,000 Deaths')
plt.title('HIV Deaths by Race')
# Out:
# Text(0.5, 1.0, 'HIV Deaths by Race')

# %%
#creating barchart to compare flu-related deaths
sns.barplot(x='Year', y='Flu-Related Death', hue='Race', data=df)
plt.ylabel('# of Flu-Related Deaths/100,000 Deaths')

plt.title('Flu-Related Deaths by Race')
# Out:
# Text(0.5, 1.0, 'Flu-Related Deaths by Race')

# %%
#creating barchart to compare cancer deaths
sns.barplot(x='Year', y='Cancer Death', hue='Race', data=df)
plt.ylabel('# of Cancer Deaths/100,000 Deaths')

plt.title('Cancer Deaths by Race')
# Out:
# Text(0.5, 1.0, 'Cancer Deaths by Race')

# %%
#creating barchart to compare heart disease deaths
sns.barplot(x='Year', y='Heart Disease Death', hue='Race', data=df)
plt.ylabel('# of Heart Disease Deaths/100,000 Deaths')

plt.title('Heart Disease Deaths by Race')
# Out:
# Text(0.5, 1.0, 'Heart Disease Deaths by Race')

# %%
#creating barchart to compare diabetes deaths
sns.barplot(x='Year', y='Diabetes Death', hue='Race', data=df)
plt.ylabel('# of Diabetes Deaths/100,000 Deaths')
plt.title('Diabetes Deaths by Race')
# Out:
# Text(0.5, 1.0, 'Diabetes Deaths by Race')

# %%
#creating barchart to compare homicide
sns.barplot(x='Year', y='Homicide ', hue='Race', data=df)
plt.ylabel('# of Homicide Deaths/100,000 Deaths')
plt.title('Homicide Deaths by Race')
# Out:
# Text(0.5, 1.0, 'Homicide Deaths by Race')

# %%
#creating barchart to compare suicide
sns.barplot(x='Year', y='Suicide', hue='Race', data=df)
plt.ylabel('# of Suicide Deaths/100,000 Deaths')
plt.title('Suicide Deaths by Race')
# Out:
# Text(0.5, 1.0, 'Suicide Deaths by Race')

# %%
# Finding the relations between the variables.
plt.figure(figsize=(20,10))
c= df.corr()
sns.heatmap(c,annot=True)
c
# Out:
#
# %%
import numpy as np
def reweight_distribution(original_distribution, temperature=0.5):
    distribution = np.log(original_distribution) / temperature
    distribution = np.exp(distribution)
    return distribution / np.sum(distribution)

# %%
import keras
import numpy as np
path = keras.utils.get_file('nietzsche.txt',origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 1us/step
# Corpus length: 600893

# %%
maxlen = 60
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
char_indices = dict((char, chars.index(char)) for char in chars)
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
        y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %%
from keras import layers
model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys
for epoch in range(1, 60):
    print('epoch', epoch)
    model.fit(x, y, batch_size=128, epochs=1)
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')
    
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            generated_text += next_char
            generated_text = generated_text[1:]
            sys.stdout.write(next_char)
# Out:
# epoch 1
# 1565/1565 [==============================] - 255s 163ms/step - loss: 1.7824
# --- Generating with seed: "they themselves. with equal right they might
# call themselves"
# ------ temperature: 0.2
# they themselves. with equal right they might
# call themselves and the sumple the such and the such and the sumple the such and the self-conted the sele the something the such pleasure in the experience the sumple of the self-contempting the sead the mately the self-conted the sense the sense the such a the such and the same the sumple the self-contest the sumple the sele the same the man the sumple the suld the same of the sele and the such and the such and------ temperature: 0.5
#  the suld the same of the sele and the such and the such and to the scould condering and deselved to himself to his searly defeation of the master all not the self-condects the master in the sake the really the experience for the ordent more and matelly intelled from the experience with the individual the great
# the greatest interpire the suld of the self-which person the presenting the gertal, and intellication of the extent they has despect of the sunding------ temperature: 1.0
#  intellication of the extent they has despect of the sunding enop.nest proweman- a sivilnged to the varies ralod it har only nature
# of the kosten knows unywill testances cantitto to be secobversherfuled-diverse bicatits of
# thought, wheeftheately the so great hhmooty now com religitior ttry abouter, in pulses it we man of infundivegden a
# condicater find the mark with we sevem sum.ing to mishaget be deinest
# in the undedgeness of whether andoz" broded findle ------ temperature: 1.2
#  deinest
# in the undedgeness of whether andoz" broded findle the
# "endughing--hure but is all
# to the greeth peed spiensm, here mikess, that the enlaty. this lolgies--hamsele im looking class, are-hesthed to chrirble
# outb? "who onlicyesy hywomentipe for the beliefss pertatic he presain ifs he ard know philosophyaration souls! in east atouth.;t in. the othes hic extredectunt of that the
# "cave of zadly consubtits.
#
# rake, nece, that he hosis of revelopmry is whoepoch 2
# 1565/1565 [==============================] - 326s 208ms/step - loss: 1.5850
# --- Generating with seed: "slowly as possible"!
# a thinker who has the future of europe "
# ------ temperature: 0.2
# slowly as possible"!
# a thinker who has the future of europe is the such a man of the distrust of the self-dermant of the existing the more profound the presenting the same the same the spirit and the same the same the such a percention of the existing the such a more of the such a such a percerves and such the such a profound to every and the exister and such a man of the such a man of the such a sorition and the commanding the common the same the such a m------ temperature: 0.5
# sorition and the commanding the common the same the such a most the degree to the
# super and success and the can periog and from extention that and ather and rangerousness of profound the more stands and the emotion the serming attaince of reason which it has not he has only the emoning the science in the can the arthers is in the such as who would like in the spirit and the sunder the condition of commenders to the same to a not own and percause and the in------ temperature: 1.0
#  commenders to the same to a not own and percause and the individmal, eul to
# botheriouss one of the prevoluntally they art, that have a moral to buck proin!
# the carrames
# its theretical anym, somounwed, ataest
# not
# intensestnevetion.
#
#  privilion of thicuse anabery (and
# rulinging love our bader, has that tasce, tood , remornt,
# and held an relirious and intellitadlety, who dee is give to but somean
# armath he safter
# person and more gensist and noce from the als------ temperature: 1.2
# math he safter
# person and more gensist and noce from the alsummatiov of attimly inneriesal a period logking mo times andiferthine oldic.. becumencously.".
#
# guen there: f verdait, amout the spect order of eper
# feen--and must arthotherdency  reamodder, that is the funt issume reason. hut, rimuited without poit arationiati: esceed and artuil!--levitelytanhoussy noadd
# theiop--and menifing. there has hery great own open taves wh chen plrusucents to a constoult epoch 3
# 1565/1565 [==============================] - 215s 137ms/step - loss: 1.5119
# --- Generating with seed: "e his stand in this matter upon the immense
# rationality of a"
# ------ temperature: 0.2
# e his stand in this matter upon the immense
# rationality of a comparising the reason the sense of the same the most seems the sense of the sense of the same the most sense of the sense of the individual the sense of the world and the man of the experience and the sense of the sense of the same the sense of the world and the sense of the world and the prending and the same the sense of the soul of the experiance of the individual and the man in the comparisi------ temperature: 0.5
# he experiance of the individual and the man in the comparisic of the hast for the betiment has regards a dispirmine the religious in the compariss and worsher as the same the sense of the "comparising properting the comprehensibitious in the comparis only that it is it is the expendance of the plantic power of the hast oneself, and the man
# he protect and the believe the worsh acts of the one in the sange to comes of a
# paste of the religious play and the ma------ temperature: 1.0
# e sange to comes of a
# paste of the religious play and the mankind nowledge is
# lat in still we symeators--the ratis, the voluage, as a compare europeasing-appeased under the deligiof, has greece, "so findlized and
# nothings, he casted proac;e is an one
# protes man accuastic afficm to it be super-and also comparish, it were in trueme. the pro=es saent eaugh; then its own instincts
# of enthpingung asservate humanest only
# we does naturally coment intensums, anne------ temperature: 1.2
# rvate humanest only
# we does naturally coment intensums, anneg. its
# volicle present and senses,gaptine distrust
# hiws  ement!--"is noes nadesing tringe of religions coment rathing right
# asascy the -nessifin in the weam ruves, all own uppendec of justveny be-ample, in finguugh torany in pretuint!--tinsorates a rnkemate, breaked in by its nriemb's youn thing he done moral rest
# enceration of ceasist stive
# (are-theilly, when at ova of
# s, they reason
# inteal geniuepoch 4
# 1565/1565 [==============================] - 310s 198ms/step - loss: 1.4710
# --- Generating with seed: "ons is ultimately
# also the spell of physiological valuations"
# ------ temperature: 0.2
# ons is ultimately
# also the spell of physiological valuations, and the sense of the concernication of the sense of the sense of the sense of the science of the greater and the conscious many of the greatest of the world be the world be stand the sentiment of the more intellice and still and all the sense of the science, and the senses of the world and more belief a man be explain of the precess of the science of the same has a soul, and the fact the sense o------ temperature: 0.5
# the science of the same has a soul, and the fact the sense of the world deal has a spirit and good as the best from his conscience of lightly and its termorianic is a judgment of
# the reason,
# the lable of the highest instinct,
# spirit and all the former spirits as the reariation of the higher one's world not be a man a sympathic grownd shall best many distrust of the spirits and all good and all the fact and precering and reason
# and the same must the hand ar------ temperature: 1.0
#  fact and precering and reason
# and the same must the hand are delisable even thrugh so who itself, the chaduce of
# ssupare opposine-infinedly, sympath usilism has hitherto there is not
# to the deatifered consciousness,--and whyt of the "bad.
#
# -lendess upon act travitesed siultifaitates origst that while allow ankimary
# stullf"
# intermination. there is this eacon-when learne, the certainty, armer saccly that the rendler
# thrrring
# overings, those espiritance
# and ------ temperature: 1.2
# y that the rendler
# thrrring
# overings, those espiritance
# and tuch certain, in simuricetion
# ctrablrisless, and
# god-elfouminingnooried, have peacied,
# no wort
# rebullive
# skeshtopthy, among greek german hoster mored ised cain--spon,s. nor-nether--divalted
# tradicity.b
# canter,
# at slive
# to;
# by
# individuousudaition a strowsed were dew a instance, couica
# sid, and his tite ferstaplity of
# historylabiliorsts," more, the hathed
# nothum enth ageres apperabl artitise our idaepoch 5
# 1565/1565 [==============================] - 298s 190ms/step - loss: 1.4430
# --- Generating with seed: "benevolence, sympathy, considerateness,
# moderation and the l"
# ------ temperature: 0.2
# benevolence, sympathy, considerateness,
# moderation and the light to the problem of the most an all the conscience of the problem and his spirit and the problem of the strength to the constant of the false and the our fundamental works and the most such an individual to the problem of the problem of the origination of the superiously and the words of the problem of the heart and the constant of the sense of the strength to the spirit and something and the c------ temperature: 0.5
#  sense of the strength to the spirit and something and the consists in the individual in the species and in the others as the subtle non under the same of the most strength of the future of the works the most superial himself the one any, the interminity so problem and constantly and the new command of the states of the most tyquent of the consists and taken the thing and the most such antidity and some is is to the light this way of the mists and an attai------ temperature: 1.0
# d some is is to the light this way of the mists and an attaided from this putving-ten the grans in their bry-nembgetively towingebol soberable
# consequent for the matter docious consence, exception,    guent of them, when the snays ratest nouth-peilactorishd   clusions
# and does strength of the pronger, and as all  rogic frundamentily are so unttancal an acpor ult: in how hernes, the whookes evil, the nise" as one god-malge the pray. so rignic the comfeious ------ temperature: 1.2
# he nise" as one god-malge the pray. so rignic the comfeious to profound his find, let us account with touthure have wort, bothes will from ge, prompting has eventdes firs sy", a falagivation!
#
# 1miph lays
# tembern, -siur?
#
# wi.  es how mome, these is peil look all right cases one our psoche contrary (or
# you but beenes in
# eages good nor after be reasped their idake too a lince.--at themselves preta
# from his attoony respecticutic
# rearing of the naturements and epoch 6
# 1565/1565 [==============================] - 297s 190ms/step - loss: 1.4216
# --- Generating with seed: "enefit of which the uses will perhaps first become evident i"
# ------ temperature: 0.2
# enefit of which the uses will perhaps first become evident in the same and the sense of the same in the standard of the same and the self the same to the same as a man who has he should it is the presence of the same the strong the same in the self-moral every conscience of the same and the sense of the spirit of the spirit of the same intermitious in the present the self-consequently see the same strength of the stronger the strenger of the same discious ------ temperature: 0.5
#  strength of the stronger the strenger of the same discious and the self-namely seems that man in the same and the person of the spirit the manics, and something doman be produce and annally, which the
# desire the spirit of the rable individual creal belief the value of the same one is the man of a delights of the self-derinate of the german soul and scien to the most inmears and woman with an individual and man part of such an individual and one may be des------ temperature: 1.0
# vidual and man part of such an individual and one may be destructed does a regard cimposeling the
# on. his true to editiful of progers of a german hare in error.
#
#
# n rarrfion, of will nebeder has less whoever, which i really the trake sweenled with the faith-any, whom the owommorablly speck of subjectatiom of the still, and desences madefce, and under of the mastercable trabblers, the
# inmucros-but fundamental conmolitus far the
# question. no seast?
# inamilith------ temperature: 1.2
# fundamental conmolitus far the
# question. no seast?
# inamilither; blish true the aoxy
# much will good praise, conduct hemonoge. with steedy to mner.
#
# , heow fiouful to take berouk free whodo
# agational cerverts of domlise,--sloga rcely.
# there decisime
# the unifier
# to the lave trage.
# fol
# ,
# before (green rareful corracied, on an also most inance in the destivolible incmirves as
# someth),
# certain circumsestal kant experience things truth toward-wilder the valiges fepoch 7
# 1127/1565 [====================>.........] - ETA: 7:38 - loss: 1.4004
